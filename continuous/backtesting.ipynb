# %%
from continuous import components

# %%
markets = [
    'BTCUSDT',
    'SOLUSDT',
    'DUSKUSDT',
    'ETHUSDT',
    'OMUSDT',
    'AVAXUSDT',
    # 'DOGEUSDT',
    # 'FLOKIUSDT',
    'YGGUSDT',
]

# %%
strategies = [
    'ichitrend', 
    'emaroc', 
    'hmaroc'
    ]
# lookback window options: '4 years', '3 years', '2 years', '1 year', '6 months', '3 months', '1 month', '1 week'
trader = components.Trader(markets, dyn_weight_lb='1 week', fc_weighting=True, port_weights='flat', strat_list=strategies, keep_records=False, leverage=1, live=False)
trader.run_backtests(window='1 year',show_stats=True, plot_rtns=False, plot_forecast=False, plot_sharpe=False, plot_pnls=True, inspect_substrats=False)
# Out:
# Trader initialised at 25/03/2024 12:43:36
# flat Total Rtn: 4x, Sharpe: 2.67, Mean Rtn: 159.1%, Stdev: 0.60, Skew: 1.95, Max dd: 19.3%, Avg dd: 13.2%
# ...

# %% [markdown]
# i think the layer 1 and ai naratives have both run out of steam for now, so i need a new portfolio of maybe rwa and gaming coins
# also i need to sort out the situation with standardising, normalising (individually and combined 'scaling'), dynamic weighting and clipping. that's 4 ways i'm manipulating the forecasts between when they're generated and when they're actually used, it's no wonder they are losing a lot of their meaning
# and maybe consider using the vwmas instead of closing prices
# and other trend-following strats
# and other completely different strats like vwap bands
